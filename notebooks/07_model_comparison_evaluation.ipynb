# %% [markdown]
# # Comprehensive Model Evaluation and Comparison Framework
#
# ## Executive Summary
#
# This notebook provides a systematic evaluation and comparison of all implemented churn prediction models using standardized metrics, cross-validation protocols, and business impact assessment. The analysis supports model selection for production deployment.
#
# ## Objectives
#
# 1. **Performance Benchmarking**: Standardized evaluation across multiple metrics and datasets
# 2. **Cross-Validation Analysis**: Robust performance estimation with confidence intervals
# 3. **Model Interpretability**: SHAP analysis and feature importance comparison
# 4. **Computational Efficiency**: Training time and inference speed benchmarking
# 5. **Production Readiness**: Model stability, calibration, and deployment recommendations
#
# ## Evaluation Framework
#
# - **Metric Portfolio**: Accuracy, Precision, Recall, F1, AUC-ROC, AUC-PR, and business metrics
# - **Statistical Testing**: McNemar's test and Friedman test for model comparison
# - **Calibration Analysis**: Reliability diagrams and Brier score decomposition
# - **Fairness Assessment**: Demographic parity and equalized odds evaluation

# %%
# Model Evaluation and Comparison Environment
import warnings
warnings.filterwarnings('ignore')

# Core Libraries
import sys
import os
from pathlib import Path
import numpy as np
import pandas as pd
from typing import Dict, List, Tuple, Optional, Any
import joblib
from dataclasses import dataclass
import time

# Model Evaluation
from sklearn.metrics import (classification_report, confusion_matrix, roc_auc_score, 
                           precision_recall_curve, roc_curve, calibration_curve,
                           brier_score_loss, log_loss)
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.calibration import CalibratedClassifierCV

# Statistical Testing
from scipy.stats import mcnemar, friedmanchisquare
import statsmodels.api as sm

# Model Interpretation
import shap
from lime import lime_tabular

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Project Utilities
sys.path.append(str(Path.cwd().parent))
from utils.data_preprocessing import load_telco_data, prepare_data_for_modeling

# Configuration
np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')

print("Model evaluation framework initialized")
