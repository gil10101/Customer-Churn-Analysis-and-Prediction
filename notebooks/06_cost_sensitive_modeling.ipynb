# %% [markdown]
# # Cost-Sensitive Churn Prediction: Business-Optimized Machine Learning
#
# ## Executive Summary
#
# This notebook implements cost-sensitive machine learning approaches that optimize business outcomes rather than traditional accuracy metrics. The analysis incorporates customer acquisition costs, retention costs, and customer lifetime value to develop financially-optimized prediction models.
#
# ## Objectives
#
# 1. **Cost Matrix Development**: Quantification of false positive and false negative costs
# 2. **Threshold Optimization**: ROI-based decision threshold calibration
# 3. **Algorithm Adaptation**: Cost-sensitive variants of classification algorithms
# 4. **Business Impact Modeling**: Expected value calculation and profit optimization
# 5. **Sensitivity Analysis**: Robustness testing across different cost scenarios
#
# ## Economic Framework
#
# - **Customer Lifetime Value**: Statistical modeling of CLV based on tenure and spending patterns
# - **Acquisition Cost Analysis**: CAC calculation and payback period estimation
# - **Intervention Costs**: Retention campaign cost modeling with success probability
# - **Profit Maximization**: Mathematical optimization of decision thresholds for maximum expected profit

# %%
# Cost-Sensitive Machine Learning Environment
import warnings
warnings.filterwarnings('ignore')

# Core Libraries
import sys
import os
from pathlib import Path
import numpy as np
import pandas as pd
from typing import Dict, List, Tuple, Optional
from dataclasses import dataclass

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import xgboost as xgb
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

# Cost-Sensitive Libraries
from costcla.models import CostSensitiveLogisticRegression, CostSensitiveRandomForestClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# Optimization
from scipy.optimize import minimize_scalar
import optuna

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Project Utilities
sys.path.append(str(Path.cwd().parent))
from utils.data_preprocessing import load_telco_data, prepare_data_for_modeling
from utils.cost_sensitive_utils import calculate_clv, calculate_intervention_costs

# Configuration
np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')

print("Cost-sensitive modeling environment initialized")
