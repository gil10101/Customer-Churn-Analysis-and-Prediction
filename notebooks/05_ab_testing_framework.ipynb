# %% [markdown]
# # A/B Testing Framework: Statistical Experimentation for Retention Strategies
#
# ## Executive Summary
#
# This notebook implements a comprehensive A/B testing framework for evaluating customer retention strategies. The analysis includes power analysis, sample size determination, statistical testing, and business impact quantification.
#
# ## Objectives
#
# 1. **Experimental Design**: Power analysis and sample size calculation for retention experiments
# 2. **Strategy Simulation**: Monte Carlo simulation of different retention interventions
# 3. **Statistical Testing**: Hypothesis testing with appropriate correction for multiple comparisons
# 4. **Effect Size Quantification**: Cohen's d, relative risk, and confidence interval estimation
# 5. **Business Impact Assessment**: ROI analysis and cost-benefit evaluation
#
# ## Methodological Framework
#
# - **Randomization Protocol**: Stratified randomization ensuring balanced treatment assignment
# - **Power Analysis**: Statistical power calculation with effect size sensitivity analysis
# - **Multiple Testing**: Bonferroni and FDR correction for family-wise error control
# - **Bayesian Methods**: Bayesian A/B testing with posterior probability estimation

# %%
# A/B Testing Analysis Environment
import warnings
warnings.filterwarnings('ignore')

# Core Libraries
import sys
import os
from pathlib import Path
import numpy as np
import pandas as pd
from typing import Dict, List, Tuple, Optional
from dataclasses import dataclass

# Statistical Testing
from scipy import stats
from scipy.stats import ttest_ind, chi2_contingency, mannwhitneyu
import statsmodels.api as sm
from statsmodels.stats.power import ttest_power
from statsmodels.stats.proportion import proportions_ztest

# Bayesian Analysis
import pymc as pm
import arviz as az

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Project Utilities
sys.path.append(str(Path.cwd().parent))
from utils.data_preprocessing import load_telco_data

# Configuration
np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')

print("A/B testing framework initialized")
